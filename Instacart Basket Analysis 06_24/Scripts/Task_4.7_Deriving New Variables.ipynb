# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\vikra\Instacart Basket Analysis 06_24'

# %%
df_merged = pd.read_csv( r'C:\Users\vikra\Instacart Basket Analysis 06_24\Data\Prepared Data\ords_prods_merge.csv', index_col = False)

# %%
df_merged.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'product_id', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'order_id', 'add_to_cart_order', 'reordered',
#        'user_id', 'eval_set', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order', 'merge_indicator'],
#       dtype='object')

# %%
df_merged.shape
# Out:
# (32433030, 17)

# %%
df = df_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_11128\3677927974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    659418
# Low-range product    331238
# High range             9344
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_11128\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices']<= 15) & (df['prices'] >5), ' price_range_loc'] = 'Mid-range product'
# Out:
# C:\Users\vikra\AppData\Local\Temp\ipykernel_11128\121067480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df['prices']<= 15) & (df['prices'] >5), ' price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    659418
# Low-range product    331238
# High range             9344
# Name: count, dtype: int64

# %%
for X in range(30, 45):
print("My age is %d" % (X))
# Out:
#   Cell In[26], line 2
#     print("My age is %d" % (X))
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
df_merged['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6209410
# 1    5665604
# 6    4500101
# 2    4217610
# 5    4209334
# 3    3843929
# 4    3787042
# Name: count, dtype: int64

# %%
result = []

for value in df_merged['order_dow']:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_merged['busiest_day'] = result

# %%
df_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22436578
# Busiest day        6209410
# Least busy         3787042
# Name: count, dtype: int64

# %% [markdown]
# # 2. Check which days are busiest and slowest

# %% [markdown]
# # create label for Busiest Days

# %%
df_merged['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    6209410
# 1    5665604
# 6    4500101
# 2    4217610
# 5    4209334
# 3    3843929
# 4    3787042
# Name: count, dtype: int64

# %%
df_merged.loc[df_merged['order_dow'].isin([0, 1]), 'busiest_days'] = 'Busiest Days'

# %% [markdown]
# # create label for slowest days

# %%
df_merged.loc[df_merged['order_dow'].isin([3, 4]), 'busiest_days'] = 'Slowest Days'

# %%
 # create label for regular days
df_merged.loc[df_merged['order_dow'].isin([6, 2, 5]), 'busiest_days'] = 'Regularly busy Days'

# %%
df_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy Days    12927045
# Busiest Days           11875014
# Slowest Days            7630971
# Name: count, dtype: int64

# %% [markdown]
# # 3. Check the values of this new column for accuracy.

# %%
#confirm total number of counts are equal for both new columns
df_merged['busiest_day'].shape == df_merged['busiest_days'].shape
# Out:
# True

# %%
df_merged['busiest_day'].shape
# Out:
# (32433030,)

# %%
df_merged['busiest_days'].shape
# Out:
# (32433030,)

# %%
df_merged.head ()
# Out:
#    Unnamed: 0.1  Unnamed: 0  product_id                product_name  aisle_id  \
# 0             0           0           1  Chocolate Sandwich Cookies        61
# 1             1           0           1  Chocolate Sandwich Cookies        61
# 2             2           0           1  Chocolate Sandwich Cookies        61
# 3             3           0           1  Chocolate Sandwich Cookies        61
# 4             4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  add_to_cart_order  reordered  user_id  \
# 0             19     5.8      1107                  7          0    38259
# 1             19     5.8      5319                  3          1   196224
# 2             19     5.8      7540                  4          1   138499
# 3             19     5.8      9228                  2          0    79603
# 4             19     5.8      9273                 30          0    50005
#
# ...

# %% [markdown]
# # Observation :
# As we might expect, the  value counts of both columns  are perfectly equal because
# we have made  group of 2 or 3 days instead 1 or 5 days.
# We could  see that the total counts are equal

# %% [markdown]
# # 4. Check the busiest hours of the day

# %%
df_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2764288
# 11    2738483
# 14    2691448
# 15    2664420
# 13    2663169
# 12    2620719
# 16    2537358
# 9     2456591
# 17    2089385
# 8     1719888
# 18    1637858
# 19    1259335
# 20     976991
# 7      891900
# 21     796341
# 22     634715
# 23     402593
# 6      290763
# 0      218925
# 1      115780
# 5       88054
# 2       69429
# 4       53280
# 3       51317
# Name: count, dtype: int64

# %%
hours_sorted = df_merged['order_hour_of_day'].value_counts(dropna = False).index.to_numpy()

# %%
df_merged.loc[df_merged['order_hour_of_day'].isin([10,11 ,14 , 15, 13,12 , 16, 9]), 'busiest_hours'] = 'Most orders'

# %%
df_merged.loc[df_merged['order_hour_of_day'].isin([17, 8 , 18 ,19 ,20, 7, 21, 22]), 'busiest_hours'] = 'Average orders'

# %%
df_merged.loc[df_merged['order_hour_of_day'].isin([ 23, 6, 0, 1, 5, 2, 4, 3]), 'busiest_hours'] = 'Fewest orders'

# %% [markdown]
# # 5. Checking the frequency for this new column

# %%
df_merged['busiest_hours'].value_counts(dropna = False)
# Out:
# busiest_hours
# Most orders       21136476
# Average orders    10006413
# Fewest orders      1290141
# Name: count, dtype: int64

# %%
df_merged = df_merged.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0', 'merge_indicator'])

# %%
df_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  add_to_cart_order  reordered  user_id eval_set  order_number  \
# 0      1107                  7          0    38259    prior             2
# 1      5319                  3          1   196224    prior            65
# 2      7540                  4          1   138499    prior             8
# 3      9228                  2          0    79603    prior             2
# 4      9273                 30          0    50005    prior             1
#
# ...

# %%
df_merged.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'ords_prods_merged_derived.pkl'))
